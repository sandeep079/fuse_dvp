# %% [markdown]
# # Assignment: Data Visualization and Presentation - AI Fellowship
#
# ### Exploring Titannic Dataset with Data Visualizations
#
# In this assignment, I worked with the famous Titanic dataset, which contains passenger information from the ill-fated RMS Titanic voyage. The dataset includes demographic, travel, and survival details such as passenger class, age, gender, fare, embarkation port, and family relationships.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotchecker import PlotChecker

# %% [markdown]
# ## Importing Data

# %%
df = pd.read_csv("/home/sandy/fusemachine/fuse_dvp/titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Data Descriptions
#
#
# - **survived**: Whether the passenger survived (0 = No, 1 = Yes)
#
# - **pclass**: Ticket class (1 = 1st class, 2 = 2nd class, 3 = 3rd class)
#
# - **sex**: Gender of the passenger (male/female)
#
# - **age**: Age of the passenger in years
#
# - **sibsp**: Number of siblings/spouses aboard
#
# - **parch**: Number of parents/children aboard
#
# - **fare**: Passenger fare in British pounds
#
# - **embarked**: Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# - **class**: Ticket class (First/Second/Third) - same as pclass but as text
# - **who**: Demographic category (man/woman/child)
# - **adult_male**: Whether passenger was an adult male (True/False)
# - **deck**: Cabin deck level (A-G)
# - **embark_town**: Port of embarkation (full name)
# - **alive**: Survival status (no/yes) - same as survived but as text
# - **alone**: Whether passenger traveled alone (True/False)

# %% [markdown]
# ### BASIC PLOTTING TASKS

# %%
### Ex-1-Task-1
fig, ax = plt.subplots(figsize=(8, 5))
# Plot a histogram to explore the distribution of fare in the dataset.
# Keep the title of the plot "Fare Distribution"
### BEGIN SOLUTION 
# YOUR CODE HERE
sns.histplot(df['fare'], bins=30, kde=True, ax=ax)
ax.set_title("Fare Distribution") 
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Fare Distribution')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-1-Task-2
# Create a scatterplot to explore the relationship between Age and Fare.
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION 
# YOUR CODE HERE
sns.scatterplot(data=df, x='age', y='fare', ax=ax)
ax.set_title("Age vs Fare")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Age vs Fare')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-1-Task-3
# Plot average fare by embarked using a line chart.
# Set Title: "Average fare by embarked port"
# Use 'x' marker
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION 
# YOUR CODE HERE
avg_fare_by_dept = df.groupby('embarked')['fare'].mean().reset_index()
sns.lineplot(data=avg_fare_by_dept, x='embarked', y='fare', marker='x', ax=ax)
ax.set_title("Average Fare by Embarked Port")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Average Fare by Embarked Port')

# %%
# INTENTIONALLY LEFT BLANK

# %% [markdown]
# ### UNIVARIATE ANALYSIS TASKS

# %%
### Ex-2-Task-1
# Create a boxplot to visualize the distribution of Age.
# Set title: Boxplot of Age
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION 
# YOUR CODE HERE
sns.boxplot(data=df, x='age', ax=ax)
ax.set_title("Boxplot of Age")

### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Boxplot of Age')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-2-Task-2
# Plot a bar chart showing the count of each class level.
# Set title: "Class Level Count"
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION 
# YOUR CODE HERE
sns.countplot(data=df, x='class', ax=ax)
ax.set_title("Class Level Count")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Class Level Count')

# %%
# INTENTIONALLY LEFT BLANK

# %% [markdown]
# ### BIVARIATE ANALYSIS TASKS

# %%
### Ex-3-Task-1
# Create a scatterplot of sibsp vs fare, colored by Gender.
fig, ax = plt.subplots(figsize=(8, 5))
### BEGIN SOLUTION 
# YOUR CODE HERE
sns.scatterplot(data=df, x='sibsp', y='fare', hue='sex', ax=ax)
ax.set_xlabel("sibsp")  # 'sibsp' as a proxy for experience
ax.set_ylabel("fare")      # 'fare' as a proxy for salary
ax.set_title("sibsp vs fare by Gender")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'sibsp vs fare by Gender')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-3-Task-2
# Create a boxplot showing Fare distribution across Embarked.
fig, ax = plt.subplots(figsize=(10, 6))
### BEGIN SOLUTION 
# YOUR CODE HERE
sns.boxplot(data=df, x='embarked', y='fare', ax=ax)
ax.set_title("Fare Distribution by Embarked Port")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Fare Distribution by Embarked Port')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-3-Task-3
# Show correlation between numerical variables using a heatmap.
fig, ax = plt.subplots(figsize=(10, 6))
# Use seaborn heatmap
### BEGIN SOLUTION 
# YOUR CODE HERE
numeric_df = df.select_dtypes(include='number')
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap='coolwarm', ax=ax)
ax.set_title("Correlation Heatmap")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# INTENTIONALLY LEFT BLANK

# %%
### Ex-4-Task-1
# Use seaborn (declarative) to plot count of each marital status.
fig, ax = plt.subplots(figsize=(10, 6))
### BEGIN SOLUTION 
# YOUR CODE HERE
sns.countplot(data=df, x='who', ax=ax)
ax.set_title("Count of Each Marital Status")
### END SOLUTION
# Out:
# Text(0.5, 1.0, 'Count of Each Marital Status')

# %%
# INTENTIONALLY LEFT BLANK
